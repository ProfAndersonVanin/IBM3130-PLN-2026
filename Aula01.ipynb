# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAndersonVanin/IBM3130-PLN-2026/blob/main/Aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Tokenização - SIMPLES**

# %%
frase = "O processamento de linguagem natural é fascinante"
tokens = frase.split()
print(tokens)
print(f"Total de tokens: {len(tokens)}")

# %%
frase_real = "PLN é incrível! Mas também é desafiador, não é mesmo?"
tokens_raw = frase_real.split()
print(tokens_raw)
print(f"Total de tokens: {len(tokens)}")

# %% [markdown]
# Problemas encontrados neste ponto:
#
# - `'incrível!'`
# - `'mesmo?'`

# %%
import re
tokens_regex = re.findall(r'\b\w+\b', frase_real.lower())
print(tokens_regex)

# %% [markdown]
# Isso já é melhor — a pontuação some e as palavras ficam em minúsculas. Mas agora surgem novos problemas. Contrações e hífens são tratados de forma inconsistente.

# %% [markdown]
# # **2. Tokenização com NLTK**

# %%
import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)

# %%
# Recursos
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
# Tokenizador de palavras
frase_real = "PLN é incrível! Mas também é desafiador, não é mesmo?"
tokens_nltk = word_tokenize(frase_real, language='portuguese')
print(tokens_nltk)
print(f"Total de tokens: {len(tokens_nltk)}")

# %%
texto_complexo = (
	"Dr. Silva prescreveu 500mg de ibuprofeno às 8h. "
	"O Sr. João pagou R$ 42,50 na farmácia. "
	"Ele perguntou: 'Isso é suficiente?' A Dra. Ana confirmou."
)
tokens_complexos = word_tokenize(texto_complexo, language='portuguese')
print(tokens_complexos)

# %%
# Tokenização por sentenças
texto_longo = (
    "O Prof. Anderson iniciou a aula às 8h. "
    "Ele explicou que o PLN tem três eras históricas. "
    "A 1ª era foi baseada em regras, a 2ª em estatística. "
    "A 3ª era, iniciada em 2012, é dominada pelo deep learning."
)

# %%
sentencas = sent_tokenize(texto_longo, language='portuguese')
print(f"Total de sentenças: {len(sentencas)}")

# %%
for i, s in enumerate(sentencas, 1):
    print(f"  [{i}] {s}")

# %% [markdown]
# # **Comparação**

# %%
sentencas_ingenuas = texto_longo.split('.')

# %%
print(f"\nDivisão ingênua por ponto: {len(sentencas_ingenuas)} partes")

# %%
for i, s in enumerate(sentencas_ingenuas, 1):
    print(f"  [{i}] {s.strip()}")

# %% [markdown]
# # **Contar frequência de palavras**

# %%
texto_analise = """
O processamento de linguagem natural é uma das áreas mais fascinantes da inteligência artificial.
PLN permite que computadores compreendam, interpretem e gerem linguagem humana.
As aplicações de PLN incluem tradução automática, análise de sentimento, reconhecimento de entidades e sistemas de perguntas e respostas.
A linguagem humana é rica, ambígua e profundamente contextual.
Por isso, PLN é um campo desafiador e em constante evolução.
Pesquisadores de todo o mundo trabalham para tornar os sistemas de PLN mais precisos, mais robustos e mais inclusivos.
"""

# %%
# Tokenizar e converter para minusculas
tokens = word_tokenize(texto_analise.lower(), language='portuguese')
print(f"Total de tokens brutos: {len(tokens)}")
print(tokens)

# %% [markdown]
# # **Utilizando os StopWords**

# %%
import string

# %%
stop_pt = set(stopwords.words('portuguese'))

# %%
stop_pt

# %%
tokens

# %%
# Passo 1: remover stopwords
tokens_sem_stopwords = []
for token in tokens:
    if token not in stop_pt:
        tokens_sem_stopwords.append(token)

# %%
tokens_sem_stopwords

# %%
# Passo 2: remover pontuação
tokens_sem_pontuacao = []
for token in tokens_sem_stopwords:
    if token not in string.punctuation:
        tokens_sem_pontuacao.append(token)

# %%
string.punctuation

# %%
tokens_sem_pontuacao

# %%
# Passo 3: manter apenas tokens alfabéticos (sem números ou símbolos)
tokens_apenas_letras = []
for token in tokens_sem_pontuacao:
    if token.isalpha():
        tokens_apenas_letras.append(token)

# %%
tokens_apenas_letras

# %%
# Passo 4: manter apenas tokens com mais de 2 caracteres
tokens_limpos = []
for token in tokens_apenas_letras:
    if len(token) > 2:
        tokens_limpos.append(token)

# %%
tokens_limpos

# %% [markdown]
# ---

# %%
tokens_limpos = [
    token for token in tokens
    if token not in stop_pt               # não é stopword
    and token not in string.punctuation   # não é pontuação
    and token.isalpha()                   # apenas letras, sem números ou símbolos
    and len(token) > 2                    # comprimento mínimo de 3 caracteres
]

# %%
tokens_limpos

# %%
print(f"Tokens após limpeza: {len(tokens_limpos)}")
print(f"Redução: {(1 - len(tokens_limpos)/len(tokens))*100:.1f}% dos tokens removidos")
print(f"\nTokens relevantes: {tokens_limpos}")

# %% [markdown]
# # **Calculando a frequência**

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(tokens_limpos)

# %%
freq

# %%
print("Palavras mais frequentes:")
for palavra, contagem in freq.most_common(10):
    barra = "█" * contagem
    print(f"  {palavra:<20} {contagem:>2}  {barra}")

# %% [markdown]
# # **2. QUESTÕES TEÓRICAS**

# %% [markdown]
# **ATENÇÃO**:
#
# > <font color='red'>**Respostas copiadas literalmente do material da aula ou da internet sem elaboração própria não receberão pontuação máxima. O objetivo é demonstrar compreensão, não memorização.**</font>

# %% [markdown]
# # **Questão 1 — Compreensão conceitual**
# Explique, com suas próprias palavras, o que é Processamento de Linguagem Natural e por que ele é considerado uma área interdisciplinar. Mencione pelo menos duas disciplinas que contribuem para o PLN e explique de que forma cada uma contribui.

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# # **Questão 2 — Análise histórica**
# A evolução do PLN passou por três grandes eras: sistemas baseados em regras, modelos estatísticos e deep learning / Transformers. Escolha UMA dessas eras e responda:
#
# **a.**  Qual foi a principal ideia ou filosofia que guiou essa era?
#
# **b.**  Cite um sistema ou modelo real desenvolvido nessa era e descreva brevemente o que ele fazia.
#
# **c.**  Quais foram as principais limitações que levaram à transição para a era seguinte?

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# # **Questão 3 — Aplicação prática**
# Pense no seu dia a dia e identifique TRÊS situações concretas em que você usa (ou já usou) alguma aplicação de PLN — mesmo sem saber que era PLN na época. Para cada situação:
#
# **a.**  Descreva a aplicação e como você a usa.
#
# **b.**  Identifique qual tarefa de PLN está por trás dela (tradução, análise de sentimento, NER, geração de texto, etc.).
#
# **c.**  Já vivenciou alguma falha ou limitação desse sistema? Descreva.

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# # **Questão 4 — Análise de ambiguidade**
# A ambiguidade é um dos principais desafios do PLN. Para cada frase abaixo,(**i**) identifique o tipo de ambiguidade presente e (**ii**) explique as duas (ou mais) interpretações possíveis:

# %% [markdown]
# ## **item a**
#
# `'Visitei o banco ontem.'`
#
# - Tipo de ambiguidade:
#
# - Interpretação 1:
#
# - Interpretação 2:

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# ## **item b**
#
# `'A secretária bateu na porta do diretor com o relatório.'`
#
# - Tipo de ambiguidade:
#
# - Interpretação 1:
#
# - Interpretação 2:

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# ## **item c**
#
# `'Que dia lindo!' (dito por alguém preso no trânsito por 2 horas)`
#
# - Tipo de ambiguidade:
#
# - Interpretação 1:
#
# - Interpretação 2:

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# ## **item d**
#
# `'O modelo perfeito.' (em um site de moda e em um artigo de IA)`
#
# - Tipo de ambiguidade:
#
# - Interpretação 1:
#
# - Interpretação 2:

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>

# %% [markdown]
# # **Questão 5 — Reflexão crítica e perspectiva pessoal**
# Leia a afirmação abaixo e posicione-se criticamente, apresentando argumentos a favor e/ou contra:
#
# > "Com o avanço dos Modelos de Linguagem Grandes (LLMs) como o ChatGPT e o Claude,  o PLN como disciplina acadêmica se tornou desnecessário. Basta usar a API e pronto."
#
# Em sua resposta, considere:
#
# **a.**  O que se perde ao usar LLMs como 'caixas-pretas' sem compreender os fundamentos?
#
# **b.**  Quais habilidades de PLN continuam sendo relevantes mesmo com LLMs disponíveis?
#
# **c.**  Qual é a sua perspectiva pessoal sobre como o PLN vai evoluir nos próximos 5 anos?

# %% [markdown]
# <font color='red'>Sua resposta aqui...</font>
