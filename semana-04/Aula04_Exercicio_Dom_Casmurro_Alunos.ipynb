# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAndersonVanin/IBM3130-PLN-2026/blob/main/semana-04/Aula04_Exercicio_Dom_Casmurro_Alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 04: Processamento de um Texto Literário com PLN
#
# ## Exercício: Dom Casmurro, Bag of Words e TF-IDF
#
# ### Enunciado
#
# Nesta atividade, você irá aplicar técnicas de **Processamento de Linguagem Natural** para analisar um pequeno corpus inspirado no capítulo **Olhos de Ressaca**, da obra *Dom Casmurro*.
#
# O objetivo é transformar o texto em uma representação numérica que possa ser utilizada por algoritmos de Machine Learning.
#
# Você deverá construir, passo a passo, o seguinte fluxo:
#
# ```text
# TEXTO
#   ↓
# PROCESSAMENTO COM spaCy
#   ↓
# SEPARAÇÃO EM SENTENÇAS
#   ↓
# TOKENIZAÇÃO
#   ↓
# REMOÇÃO DE STOPWORDS
#   ↓
# LEMATIZAÇÃO
#   ↓
# CORPUS PROCESSADO
#   ↓
# BAG OF WORDS
#   ↓
# TF-IDF
# ```
#
# ### Objetivos
#
# Ao final da atividade, você deverá ser capaz de:
#
# 1. Utilizar o spaCy para processar um texto em português.
# 2. Separar um texto em sentenças.
# 3. Entender como cada sentença pode ser tratada como um documento.
# 4. Identificar tokens e stopwords.
# 5. Aplicar lematização.
# 6. Construir um corpus pré-processado.
# 7. Criar uma matriz Bag of Words.
# 8. Identificar as palavras mais frequentes.
# 9. Criar uma matriz TF-IDF.
# 10. Identificar palavras importantes para cada documento.
#
# > **Importante:** execute cada célula e observe os resultados antes de continuar. Em várias etapas, você deverá completar partes do código indicadas por `# COMPLETE AQUI`.

# %% [markdown]
# # 1. Preparação do ambiente
#
# Antes de começar, precisamos instalar:
#
# - spaCy
# - modelo de português
# - scikit-learn
# - pandas
#
# Execute a célula abaixo.

# %%
# !pip install -q spacy scikit-learn pandas
# !python -m spacy download pt_core_news_sm -q

# %% [markdown]
# # 2. Importando as bibliotecas
#
# Vamos utilizar:
#
# - `spacy` para o processamento linguístico.
# - `pandas` para organizar os resultados.
# - `CountVectorizer` para construir o Bag of Words.
# - `TfidfVectorizer` para calcular o TF-IDF.
#
# Complete as importações que faltam.

# %%
import spacy
import pandas as pd

# COMPLETE AQUI
# Importe CountVectorizer

# COMPLETE AQUI
# Importe TfidfVectorizer

# %% [markdown]
# # 3. Carregando o modelo de língua portuguesa
#
# O spaCy possui modelos específicos para diferentes idiomas.
#
# Neste exercício, utilizaremos:
#
# ```text
# pt_core_news_sm
# ```
#
# Esse modelo será utilizado para identificar informações linguísticas do texto.
#
# Complete o código abaixo.

# %%
# COMPLETE AQUI
# Carregue o modelo pt_core_news_sm na variável nlp

# nlp = ...

# %% [markdown]
# # 4. Nosso corpus
#
# O texto abaixo será o corpus utilizado na atividade.
#
# Observe que o texto possui várias sentenças. Posteriormente, cada sentença será considerada um **documento**.
#
# Leia o texto e execute a célula.

# %%
texto = """
Olhos de Ressaca

Capitu tinha olhos de ressaca, olhos de cigana oblíqua e dissimulada.
Bentinho procurava compreender o mistério daqueles olhos.
Pareciam puxá-lo para dentro como uma onda do mar.
Havia neles alguma coisa profunda e misteriosa.
Capitu olhava para ele de maneira fixa e intensa.
Os olhos de Capitu pareciam trazer o movimento e a força do mar.
"""

# %% [markdown]
# ## Pergunta 1
#
# Antes de continuar, responda:
#
# **Quantas sentenças você acredita que existem no texto?**
#
# Execute a célula abaixo para observar o texto completo.

# %%
print(texto)

# %% [markdown]
# # 5. Processando o texto com spaCy
#
# Agora precisamos enviar o texto para o spaCy.
#
# O resultado será armazenado em uma variável chamada `doc`.
#
# Complete o código.

# %%
# COMPLETE AQUI
# Processe a variável texto utilizando nlp

# doc = ...

# %% [markdown]
# # 6. Separando o texto em sentenças
#
# O spaCy consegue identificar automaticamente os limites das sentenças.
#
# O comando:
#
# ```python
# doc.sents
# ```
#
# permite percorrer as sentenças encontradas.
#
# Nosso objetivo é criar uma lista chamada `sentencas`.
#
# A ideia é:
#
# ```text
# sentencas
# │
# ├── Sentença 1
# ├── Sentença 2
# ├── Sentença 3
# └── ...
# ```
#
# Complete o código.

# %%
sentencas = []

# COMPLETE AQUI
# Percorra doc.sents

    # COMPLETE AQUI
    # Adicione o texto de cada sentença na lista sentencas
    pass

# %% [markdown]
# ## Visualizando as sentenças
#
# Cada sentença será tratada como um documento.
#
# Execute a célula abaixo e observe o resultado.

# %%
for i in range(len(sentencas)):
    print("DOCUMENTO", i + 1)
    print(sentencas[i])
    print()

# %% [markdown]
# ## Pergunta 2
#
# Após executar a célula anterior:
#
# 1. Quantos documentos foram criados?
# 2. Por que podemos considerar cada sentença um documento?
#
# Registre sua resposta abaixo:
#
# **Resposta:**

# %% [markdown]
# # 7. Entendendo os tokens
#
# Antes de remover stopwords e lematizar, vamos observar os tokens encontrados em uma das sentenças.
#
# Complete o código para escolher a primeira sentença e processá-la com spaCy.

# %%
# COMPLETE AQUI

# frase_exemplo = sentencas[0]

# COMPLETE AQUI

# doc_exemplo = ...

# %%
for token in doc_exemplo:
    print(
        "Texto:", token.text,
        "| Lema:", token.lemma_,
        "| Stopword:", token.is_stop
    )

# %% [markdown]
# # 8. Construindo o corpus processado
#
# Agora realizaremos o pré-processamento de todas as sentenças.
#
# Para cada sentença, devemos:
#
# 1. Processar a sentença com spaCy.
# 2. Percorrer seus tokens.
# 3. Manter apenas tokens alfabéticos.
# 4. Remover stopwords.
# 5. Obter o lema da palavra.
# 6. Converter para letras minúsculas.
# 7. Juntar as palavras novamente.
#
# O resultado esperado é uma estrutura semelhante a:
#
# ```text
# corpus_processado
# │
# ├── documento processado 1
# ├── documento processado 2
# ├── documento processado 3
# └── ...
# ```
#
# Complete o código passo a passo.

# %%
corpus_processado = []

for sentenca in sentencas:

    # 1. Processe a sentença com spaCy
    # COMPLETE AQUI
    # doc_sentenca = ...

    palavras = []

    # 2. Percorra os tokens da sentença
    # COMPLETE AQUI

        # 3. Verifique se o token é alfabético
        # COMPLETE AQUI

            # 4. Verifique se o token NÃO é uma stopword
            # COMPLETE AQUI

                # 5 e 6. Obtenha o lema em letras minúsculas
                # COMPLETE AQUI

                # Adicione a palavra à lista
                # COMPLETE AQUI

    # 7. Junte as palavras da lista em uma única string
    # COMPLETE AQUI
    # documento_processado = ...

    corpus_processado.append(documento_processado)

# %% [markdown]
# ## Verificando o resultado
#
# Execute a célula abaixo.
#
# Compare o texto original com o texto processado.
#
# Observe especialmente:
#
# - palavras removidas;
# - plural transformado em singular;
# - verbos transformados para sua forma básica.

# %%
for i in range(len(corpus_processado)):
    print("DOCUMENTO", i + 1)
    print("Original:", sentencas[i])
    print("Processado:", corpus_processado[i])
    print()

# %% [markdown]
# # 9. Removendo documentos vazios
#
# Depois da remoção de stopwords, uma sentença pode eventualmente ficar vazia.
#
# Vamos criar uma nova lista contendo apenas os documentos que possuem conteúdo.
#
# Complete o código.

# %%
corpus_final = []

for documento in corpus_processado:

    # COMPLETE AQUI
    # Verifique se o documento não está vazio

        # COMPLETE AQUI
        # Adicione o documento em corpus_final
        pass

# %%
print("Quantidade de documentos:", len(corpus_final))

for i in range(len(corpus_final)):
    print(i + 1, "-", corpus_final[i])

# %% [markdown]
# # Parte 1: Bag of Words
#
# ## 10. Criando o Bag of Words
#
# Agora vamos transformar o texto em números.
#
# O Bag of Words funciona da seguinte forma:
#
# ```text
# Documento        capitu   olho   mar   mistério
# ------------------------------------------------
# Documento 1         1       2     0       0
# Documento 2         0       1     0       1
# Documento 3         0       0     1       0
# ```
#
# Cada:
#
# - linha representa um documento;
# - coluna representa uma palavra;
# - número representa a frequência da palavra naquele documento.
#
# Complete o código.

# %%
# COMPLETE AQUI
# Crie o CountVectorizer

# vectorizer_bow = ...

# COMPLETE AQUI
# Ajuste o vectorizer ao corpus_final e transforme o corpus

# matriz_bow = ...

# %% [markdown]
# ## 11. Obtendo o vocabulário
#
# O vocabulário contém todas as palavras identificadas pelo `CountVectorizer`.
#
# Complete o código.

# %%
# COMPLETE AQUI

# vocabulario = ...

print(vocabulario)

# %% [markdown]
# ## 12. Criando uma tabela para visualizar o Bag of Words
#
# A matriz retornada pelo `CountVectorizer` precisa ser convertida para um formato mais fácil de visualizar.
#
# Use `pandas.DataFrame`.
#
# Complete o código.

# %%
# COMPLETE AQUI

# df_bow = pd.DataFrame(
#     ...
# )

df_bow

# %% [markdown]
# ## 13. Nomeando os documentos
#
# Vamos criar nomes para cada documento:
#
# ```text
# Documento 1
# Documento 2
# Documento 3
# ...
# ```
#
# Complete o código.

# %%
numeros_documentos = []

for i in range(len(corpus_final)):

    # COMPLETE AQUI
    # Crie o nome Documento 1, Documento 2, etc.

    pass

# COMPLETE AQUI
# Defina numeros_documentos como índice de df_bow

df_bow

# %% [markdown]
# # 14. Identificando as palavras mais frequentes
#
# Agora queremos responder:
#
# > Quais palavras aparecem mais vezes no corpus?
#
# Primeiro, precisamos somar os valores de cada coluna da matriz Bag of Words.
#
# Complete o código.

# %%
# COMPLETE AQUI

# frequencias = ...

# %%
df_frequencias = pd.DataFrame()

# COMPLETE AQUI
# Crie a coluna Palavra usando o índice de frequencias

# COMPLETE AQUI
# Crie a coluna Frequência usando os valores de frequencias

df_frequencias

# %% [markdown]
# ## Ordenando as palavras por frequência
#
# Para identificar as palavras mais frequentes, ordene a tabela da maior frequência para a menor.

# %%
# COMPLETE AQUI

# df_frequencias = df_frequencias.sort_values(
#     by=...,
#     ascending=...
# )

df_frequencias.head(10)

# %% [markdown]
# # Parte 2: TF-IDF
#
# ## 15. O que queremos descobrir agora?
#
# O Bag of Words informa apenas a frequência.
#
# Mas imagine duas situações:
#
# - uma palavra aparece em praticamente todos os documentos;
# - outra palavra aparece poucas vezes, mas é muito característica de apenas um documento.
#
# O TF-IDF ajuda a atribuir maior importância relativa às palavras que contribuem para diferenciar um documento dos demais.
#
# Agora vamos criar uma nova representação numérica.

# %% [markdown]
# ## 16. Criando a matriz TF-IDF
#
# Complete o código utilizando `TfidfVectorizer`.

# %%
# COMPLETE AQUI
# Crie o TfidfVectorizer

# vectorizer_tfidf = ...

# COMPLETE AQUI
# Ajuste e transforme corpus_final

# matriz_tfidf = ...

# %% [markdown]
# ## 17. Obtendo o vocabulário do TF-IDF

# %%
# COMPLETE AQUI

# vocabulario_tfidf = ...

print(vocabulario_tfidf)

# %% [markdown]
# ## 18. Transformando o TF-IDF em uma tabela
#
# Agora transforme a matriz em um DataFrame.
#
# Utilize:
#
# - `matriz_tfidf.toarray()`
# - `vocabulario_tfidf`
# - `numeros_documentos`
#
# Complete o código.

# %%
# COMPLETE AQUI

# df_tfidf = pd.DataFrame(
#     ...
# )

# COMPLETE AQUI
# Defina o índice usando numeros_documentos

df_tfidf

# %% [markdown]
# # 19. Identificando as palavras mais importantes do corpus
#
# Para descobrir a importância média de cada palavra, podemos calcular a média dos valores TF-IDF.
#
# Complete o código.

# %%
import numpy as np

# COMPLETE AQUI
# Calcule a média da matriz TF-IDF

# importancias = ...

# Transforme o resultado em um vetor simples
importancias = np.asarray(importancias).ravel()

# %%
df_importancias = pd.DataFrame()

# COMPLETE AQUI
# Crie a coluna Palavra

# COMPLETE AQUI
# Crie a coluna TF-IDF

# COMPLETE AQUI
# Ordene os resultados do maior para o menor valor

df_importancias.head(10)

# %% [markdown]
# # Parte 3: Analisando cada documento
#
# ## 20. Quais palavras caracterizam cada sentença?
#
# Agora vamos analisar os documentos individualmente.
#
# Para cada documento:
#
# 1. Selecione a linha correspondente no DataFrame TF-IDF.
# 2. Ordene os valores do maior para o menor.
# 3. Mostre as 5 palavras com maior peso.
#
# Complete o código.

# %%
for i in range(len(corpus_final)):

    print()
    print("=" * 50)
    print("DOCUMENTO", i + 1)

    print()
    print("Texto processado:")
    print(corpus_final[i])

    # COMPLETE AQUI
    # Selecione os valores TF-IDF do documento atual

    # valores = ...

    # COMPLETE AQUI
    # Ordene os valores do maior para o menor

    # valores_ordenados = ...

    print()
    print("5 palavras mais importantes:")

    # COMPLETE AQUI
    # Mostre as 5 primeiras palavras
    pass

# %% [markdown]
# # Questões finais
#
# Responda após concluir a atividade.
#
# ### 1. Corpus e documentos
#
# Quantos documentos foram criados a partir do texto?
#
# **Resposta:**
#
# ### 2. Pré-processamento
#
# Cite duas palavras que foram alteradas pela lematização.
#
# **Resposta:**
#
# ### 3. Stopwords
#
# Por que palavras como artigos, preposições e outras palavras funcionais podem ser removidas neste tipo de análise?
#
# **Resposta:**
#
# ### 4. Bag of Words
#
# Qual é a principal informação representada pelos valores da matriz Bag of Words?
#
# **Resposta:**
#
# ### 5. TF-IDF
#
# Qual é a principal diferença entre o Bag of Words e o TF-IDF?
#
# **Resposta:**
#
# ### 6. Comparação
#
# A palavra mais frequente no Bag of Words foi necessariamente a palavra com maior importância no TF-IDF?
#
# **Resposta:**
#
# ### 7. Análise
#
# Escolha uma sentença e explique quais palavras ajudam a caracterizá-la segundo o TF-IDF.
#
# **Resposta:**

# %% [markdown]
# # Desafio opcional
#
# Modifique o corpus adicionando pelo menos **três novas sentenças** relacionadas ao texto.
#
# Depois:
#
# 1. Execute novamente todo o notebook.
# 2. Observe como o vocabulário mudou.
# 3. Compare as frequências.
# 4. Verifique se os valores de TF-IDF foram alterados.
# 5. Explique por que a inclusão de novos documentos pode modificar a importância de uma palavra.
#
# ## Conclusão esperada
#
# Ao concluir o exercício, você deverá compreender que um texto precisa passar por etapas de processamento antes de ser utilizado por algoritmos de Machine Learning:
#
# ```text
# Texto bruto
#     ↓
# Processamento linguístico
#     ↓
# Tokens
#     ↓
# Remoção de informações pouco relevantes
#     ↓
# Lematização
#     ↓
# Corpus processado
#     ↓
# Representação numérica
#     ↓
# Bag of Words e TF-IDF
# ```
#
# O objetivo não é apenas executar as bibliotecas, mas compreender **como cada transformação modifica a representação do texto**.
