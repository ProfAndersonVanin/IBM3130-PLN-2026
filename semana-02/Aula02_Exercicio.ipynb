# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAndersonVanin/IBM3130-PLN-2026/blob/main/semana-02/Aula02_Exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercício Prático: Pré-processamento de Texto com NLTK e spaCy**
#
# Neste exercício, você deverá aplicar as principais técnicas de pré-processamento de texto utilizando as bibliotecas NLTK e spaCy. Ao final, será possível comparar os resultados produzidos por cada ferramenta e compreender as diferenças entre stemming e lematização.

# %% [markdown]
# ## **Texto para análise**
#
# Utilize o texto abaixo como corpus da atividade.

# %% [markdown]
# *A Inteligência Artificial (IA) está transformando diversas áreas da sociedade, como educação, saúde, indústria e segurança. Nos últimos anos, algoritmos de aprendizado de máquina tornaram-se mais eficientes e acessíveis, permitindo que empresas e instituições desenvolvam soluções inovadoras para problemas complexos. Na educação, por exemplo, sistemas inteligentes podem personalizar o aprendizado de acordo com o desempenho de cada estudante. Na saúde, modelos computacionais auxiliam médicos no diagnóstico precoce de doenças e na análise de exames. Apesar dos inúmeros benefícios, a utilização da Inteligência Artificial também levanta questões relacionadas à privacidade, ética, transparência e responsabilidade no uso dos dados. Dessa forma, torna-se fundamental que profissionais da área de tecnologia desenvolvam soluções que sejam eficientes, seguras e alinhadas aos princípios éticos.*

# %% [markdown]
# # **Questão 1**
#
# Realize a **tokenização** do texto utilizando a biblioteca *NLTK*.
#
# Ao final, responda:
#
# - Quantos tokens foram encontrados?
# - Quais são os 20 primeiros tokens?

# %% [markdown]
# # **Questão 2**
#
# Realize a **normalização** do texto.
#
# Nesta etapa você deverá:
#
# - converter todas as palavras para letras minúsculas;
# - remover os sinais de pontuação.
#
# Apresente os primeiros 30 tokens normalizados.

# %% [markdown]
# # **Questão 3**
#
# Utilize a lista de **stopwords** padrão do *NLTK* para remover palavras pouco relevantes.
#
# Em seguida responda:
#
# - Quantos tokens permaneceram?
# - Quais foram os primeiros 30 tokens obtidos?

# %% [markdown]
# # **Questão 4**
#
# Crie uma **lista personalizada de stopwords**, adicionando as seguintes palavras:

# %% [markdown]
# ```
# inteligência
# artificial
# tecnologia
# dados
# ```

# %% [markdown]
# Repita o processamento e responda:
#
# - Quantos tokens permaneceram após a remoção?
# - O resultado ficou diferente da etapa anterior? Explique.

# %% [markdown]
# # **Questão 5**
#
# Utilize o `RSLPStemmer` para aplicar *stemming* sobre o texto obtido na etapa anterior.
#
# Apresente os primeiros 30 radicais encontrados.

# %% [markdown]
# # **Questão 6**
#
# Utilize o **spaCy** para realizar a *lematização* do texto original.
#
# Apresente:
#
# - os primeiros 30 lemas;
# - cinco exemplos em que o lema seja diferente da palavra original.

# %% [markdown]
# # **Questão 7**
#
# Compare os resultados do stemming e da lematização.
#
# Monte uma tabela semelhante ao exemplo abaixo.
#
# | Palavra Original | Stemming | Lema |
# | :--- | :---: | ---: |
# | transformando | transform | transformar |
# | desenvolvendo | desenvolv | desenvolver |
# | estudantes | estud | estudante |
# | soluções | soluç | solução |
# | médicos | medic | médico |
#
#
# Responda:
#
# - Qual técnica preserva melhor o significado linguístico?
# - Qual técnica tende a ser mais rápida computacionalmente?
# - Em quais aplicações o stemming pode ser suficiente?

# %% [markdown]
# # **Questão 8**
#
# Implemente uma função chamada
#
#
# `preprocessar_nltk(texto)`
#
# A função deverá executar automaticamente:
#
# - Tokenização
# - Normalização
# - Remoção de pontuação
# - Remoção de stopwords
# - Stemming
#
# Ao final, retorne uma **lista** contendo os radicais das palavras.
#
# Teste a função utilizando o texto fornecido.

# %% [markdown]
# # **Questão 9**
#
# Implemente uma função chamada
#
# `preprocessar_spacy(texto)`
#
# A função deverá executar automaticamente:
#
# - Tokenização
# - Normalização
# - Remoção de pontuação
# - Remoção de stopwords
# - Lematização
#
# Teste a função utilizando o mesmo texto.

# %% [markdown]
# # **Questão 10**
#
# Compare os dois pipelines implementados.
#
# Preencha a tabela.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em seguida, responda:
#
# - Qual biblioteca apresentou o melhor resultado para esse texto?
# - Em quais situações você utilizaria o NLTK?
# - Em quais situações você utilizaria o spaCy?
